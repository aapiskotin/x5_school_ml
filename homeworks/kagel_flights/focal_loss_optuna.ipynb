# %% [markdown]
# # Definitions

# %%
from pathlib import Path
import pickle

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import lightgbm as lgb
from category_encoders import OrdinalEncoder
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import roc_curve, roc_auc_score
import optuna

# %%
data_path = Path('.', 'data')

# %%
RANDOM_STATE = 648

# %%
target_name = 'dep_delayed_15min'

# %% [markdown]
# # Data

# %%
train = pd.read_csv(data_path.joinpath('flight_delays_train.csv'))
test = pd.read_csv(data_path.joinpath('flight_delays_test.csv'))

# %%
train.head()
# Out:
#   Month DayofMonth DayOfWeek  DepTime UniqueCarrier Origin Dest  Distance  \
# 0   c-8       c-21       c-7     1934            AA    ATL  DFW       732
# 1   c-4       c-20       c-3     1548            US    PIT  MCO       834
# 2   c-9        c-2       c-5     1422            XE    RDU  CLE       416
# 3  c-11       c-25       c-6     1015            OO    DEN  MEM       872
# 4  c-10        c-7       c-6     1828            WN    MDW  OMA       423
#
#   dep_delayed_15min
# 0                 N
# 1                 N
# 2                 N
# 3                 N
# 4                 Y

# %%
train[target_name] = train[target_name].map({"Y": 1, "N": 0})

# %%
train[target_name].mean()
# Out:
# 0.19044

# %%
train[target_name][train.DepTime > 2400].mean()
# Out:
# 1.0

# %%
train[target_name][train.DepTime > 2400].shape
# Out:
# (17,)

# %%
train.shape
# Out:
# (100000, 9)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Month              100000 non-null  object
#  1   DayofMonth         100000 non-null  object
#  2   DayOfWeek          100000 non-null  object
#  3   DepTime            100000 non-null  int64
#  4   UniqueCarrier      100000 non-null  object
#  5   Origin             100000 non-null  object
#  6   Dest               100000 non-null  object
#  7   Distance           100000 non-null  int64
#  8   dep_delayed_15min  100000 non-null  int64
# dtypes: int64(3), object(6)
# memory usage: 6.9+ MB

# %%
test.head()
# Out:
#   Month DayofMonth DayOfWeek  DepTime UniqueCarrier Origin Dest  Distance
# 0   c-7       c-25       c-3      615            YV    MRY  PHX       598
# 1   c-4       c-17       c-2      739            WN    LAS  HOU      1235
# 2  c-12        c-2       c-7      651            MQ    GSP  ORD       577
# 3   c-3       c-25       c-7     1614            WN    BWI  MHT       377
# 4   c-6        c-6       c-3     1505            UA    ORD  STL       258

# %%
test.shape
# Out:
# (100000, 8)

# %% [markdown]
# ## Split Data

# %%
X, y = train.drop(target_name, axis=1), train[target_name]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=RANDOM_STATE)

# %% [markdown]
# # Preproc

# %% [markdown]
# ## Exploration

# %%
train.DepTime.hist()
# Out:
# <AxesSubplot:>

# %%
train.DepTime.min(), train.DepTime.max()
# Out:
# (1, 2534)

# %%
time_groups = train.groupby((train.DepTime-1) // 100)

# %%
mean_by_t = time_groups[target_name].mean()
count_by_t = time_groups[target_name].count()

plt.figure(figsize=(17, 7))

plt.plot(mean_by_t.index, mean_by_t, label='target')
plt.xticks(range(0, 26))
plt.grid()
plt.legend()

# %% [markdown]
# ## timestamp decoding

# %%
def get_ts(df):
    df['hour'] = df.DepTime // 100
    df['minute'] = df.DepTime % 100
    df['d_month'] = df.DayofMonth.str[2:].astype(int)
    df['d_week'] = df.DayOfWeek.str[2:].astype(int)
    df['month'] = df.Month.str[2:].astype(int)
    
    return df

# %% [markdown]
# ## timestamp encoding

# %%
X = get_ts(X)

# %%
X.head()
# Out:
#   Month DayofMonth DayOfWeek  DepTime UniqueCarrier Origin Dest  Distance  \
# 0   c-8       c-21       c-7     1934            AA    ATL  DFW       732
# 1   c-4       c-20       c-3     1548            US    PIT  MCO       834
# 2   c-9        c-2       c-5     1422            XE    RDU  CLE       416
# 3  c-11       c-25       c-6     1015            OO    DEN  MEM       872
# 4  c-10        c-7       c-6     1828            WN    MDW  OMA       423
#
#    hour  minute  d_month  d_week  month
# 0    19      34       21       7      8
# 1    15      48       20       3      4
# 2    14      22        2       5      9
# 3    10      15       25       6     11
# 4    18      28        7       6     10

# %%
'2021-' + X.month.astype(str) + '-' + X.d_month.astype(str).str.zfill(2) + '-' + X.hour.astype(str).str.zfill(2) + '-' + X.minute.astype(str).str.zfill(2) + '-00'
# Out:
# 0         2021-8-21-19-34-00
# 1         2021-4-20-15-48-00
# 2         2021-9-02-14-22-00
# 3        2021-11-25-10-15-00
# 4        2021-10-07-18-28-00
#                 ...
# 99995     2021-5-04-16-18-00
# 99996     2021-1-18-08-04-00
# 99997     2021-1-24-19-01-00
# 99998     2021-4-27-15-15-00
# 99999    2021-11-17-18-00-00
# Length: 100000, dtype: object

# %%
X_ = X[X.DepTime < 2400]
train['dep_dt'] = pd.to_datetime('2021-' + \
                             X_.month.astype(str).str.zfill(2) + '-' +
                             X_.d_month.astype(str).str.zfill(2) + '-' +
                             X_.hour.astype(str).str.zfill(2) + '-' +
                             X_.minute.astype(str).str.zfill(2) + '-00',
                             format='%Y-%m-%d-%H-%M-%S')

# %%
train.dep_dt.hist()
# Out:
# <AxesSubplot:>

# %%
train.groupby(train.dep_dt.dt.to_period('d'))[target_name].mean().plot()
# Out:
# <AxesSubplot:xlabel='dep_dt'>

# %%
train.groupby(train.dep_dt.dt.to_period('M'))[target_name].mean().plot()
# Out:
# <AxesSubplot:xlabel='dep_dt'>

# %%
def ts_features(df):
    X_ = df[df.DepTime < 2400]
    dep_dt = pd.to_datetime('2021-' +
                                  X_.month.astype(str).str.zfill(2) + '-' +
                                  X_.d_month.astype(str).str.zfill(2) + '-' +
                                  X_.hour.astype(str).str.zfill(2) + '-' +
                                  X_.minute.astype(str).str.zfill(2) + '-00',
                                  format='%Y-%m-%d-%H-%M-%S')
    dep_td = dep_dt - pd.to_datetime('2021-01-01')
    df['days_since_ny'] = dep_td.dt.days
    df['secs_since_ny'] = dep_td.dt.seconds
    
    return df

# %% [markdown]
# ## Category encoding

# %%
cat_cols = X_train.select_dtypes(include=[object, 'category']).columns

# %%
cat_cols
# Out:
# Index(['Month', 'DayofMonth', 'DayOfWeek', 'UniqueCarrier', 'Origin', 'Dest'], dtype='object')

# %%
enc = OrdinalEncoder(cols=cat_cols,
                     handle_missing='return_nan',
                     handle_unknown='return_nan')

# %%
# %%time
enc.fit(X_train[cat_cols])
print('Done')
# Out:
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# Done
# CPU times: user 153 ms, sys: 16.5 ms, total: 170 ms
# Wall time: 273 ms

# %% [raw]
# %%time
# X_test[cat_cols] = enc.transform(X_test[cat_cols])
# X_test[cat_cols] = X_test[cat_cols].astype('category')

# %% [markdown]
# ## Sin/cos ts processing

# %%
t_limits = {'minute': (0, 59),
             'hour': (0, 23),
             'd_week': (1, 7),
             'd_month': (1, 31),
             'month': (1, 12),
             'days_since_ny': (0, 364)}

# %%
def sin_cos(df):
    for col_name, limits in t_limits.items():
        max_val = limits[1]
        min_val = limits[0]
        if col_name == 'hour':
            orig_vals = df[col_name].clip(upper=max_val)
        else:
            orig_vals = df[col_name]
        df[col_name + '_sin'] = np.sin(2*np.pi/(max_val - min_val)*orig_vals)
        df[col_name + '_cos'] = np.cos(2*np.pi/(max_val - min_val)*orig_vals)
        
    return df

# %% [markdown]
# ## Sum up prepocessing

# %%
def preproc(df):
    df = get_ts(df)
    df = ts_features(df)
    df = sin_cos(df)
    
    df[cat_cols] = enc.transform(df[cat_cols])
    df[cat_cols] = df[cat_cols].astype('category')
    
    # Special features
    df['after_midnight'] = 0
    df.loc[df.DepTime > 2400, 'after_midnight'] = 1
    
    return df

# %%
# %%time
X_train = preproc(X_train)
X_test = preproc(X_test)
# Out:
# <ipython-input-21-0555f0c157ea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hour'] = df.DepTime // 100
# <ipython-input-21-0555f0c157ea>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df.DepTime % 100
# <ipython-input-21-0555f0c157ea>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_month'] = df.DayofMonth.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_week'] = df.DayOfWeek.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df.Month.str[2:].astype(int)
# <ipython-input-29-6ca10571684d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['days_since_ny'] = dep_td.dt.days
# <ipython-input-29-6ca10571684d>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['secs_since_ny'] = dep_td.dt.seconds
# <ipython-input-35-02630819fc8c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col_name + '_sin'] = np.sin(2*np.pi/(max_val - min_val)*orig_vals)
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# <ipython-input-36-f252a9bbd96d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['after_midnight'] = 0
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# <ipython-input-21-0555f0c157ea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hour'] = df.DepTime // 100
# <ipython-input-21-0555f0c157ea>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df.DepTime % 100
# <ipython-input-21-0555f0c157ea>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_month'] = df.DayofMonth.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_week'] = df.DayOfWeek.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df.Month.str[2:].astype(int)
# CPU times: user 1.45 s, sys: 108 ms, total: 1.56 s
# Wall time: 1.64 s
# <ipython-input-29-6ca10571684d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['days_since_ny'] = dep_td.dt.days
# <ipython-input-29-6ca10571684d>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['secs_since_ny'] = dep_td.dt.seconds
# <ipython-input-35-02630819fc8c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col_name + '_sin'] = np.sin(2*np.pi/(max_val - min_val)*orig_vals)
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# <ipython-input-36-f252a9bbd96d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['after_midnight'] = 0
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %% [markdown]
# # Focal loss

# %%
import numpy as np
from scipy import optimize
from scipy import special

class FocalLoss:

    def __init__(self, gamma, alpha=None):
        self.alpha = alpha
        self.gamma = gamma

    def at(self, y):
        if self.alpha is None:
            return np.ones_like(y)
        return np.where(y, self.alpha, 1 - self.alpha)

    def pt(self, y, p):
        p = np.clip(p, 1e-15, 1 - 1e-15)
        return np.where(y, p, 1 - p)

    def __call__(self, y_true, y_pred):
        at = self.at(y_true)
        pt = self.pt(y_true, y_pred)
        return -at * (1 - pt) ** self.gamma * np.log(pt)

    def grad(self, y_true, y_pred):
        y = 2 * y_true - 1  # {0, 1} -> {-1, 1}
        at = self.at(y_true)
        pt = self.pt(y_true, y_pred)
        g = self.gamma
        return at * y * (1 - pt) ** g * (g * pt * np.log(pt) + pt - 1)

    def hess(self, y_true, y_pred):
        y = 2 * y_true - 1  # {0, 1} -> {-1, 1}
        at = self.at(y_true)
        pt = self.pt(y_true, y_pred)
        g = self.gamma

        u = at * y * (1 - pt) ** g
        du = -at * y * g * (1 - pt) ** (g - 1)
        v = g * pt * np.log(pt) + pt - 1
        dv = g * np.log(pt) + g + 1

        return (du * v + u * dv) * y * (pt * (1 - pt))

    def init_score(self, y_true):
        res = optimize.minimize_scalar(
            lambda p: self(y_true, p).sum(),
            bounds=(0, 1),
            method='bounded'
        )
        p = res.x
        log_odds = np.log(p / (1 - p))
        return log_odds*np.ones_like(y_true, dtype=np.float64)

    def lgb_obj(self, y_true, y_pred):
        p = special.expit(y_pred)
        return self.grad(y_true, p), self.hess(y_true, p)

    def lgb_eval(self, y_true, y_pred):
        p = special.expit(y_pred)
        is_higher_better = False
        return 'focal_loss', self(y_true, p).mean(), is_higher_better

# %% [markdown]
# # Fit

# %%
X_train.head()
# Out:
#       Month DayofMonth DayOfWeek  DepTime UniqueCarrier Origin Dest  Distance  \
# 46343   1.0        1.0       1.0     1805           1.0    1.0  1.0      1235
# 75701   2.0        2.0       2.0      819           2.0    2.0  2.0       892
# 89227   3.0        3.0       2.0      726           3.0    3.0  3.0       200
# 70825   4.0        4.0       3.0     1515           1.0    4.0  4.0       403
# 26022   5.0        5.0       4.0     1453           4.0    5.0  5.0        94
#
#        hour  minute  ...  hour_cos    d_week_sin  d_week_cos   d_month_sin  \
# 46343    18       5  ...  0.203456  8.660254e-01         0.5 -9.945219e-01
# 75701     8      19  ... -0.576680  1.224647e-16        -1.0  1.224647e-16
# 89227     7      26  ... -0.334880  1.224647e-16        -1.0 -5.877853e-01
# 70825    15      15  ... -0.576680  8.660254e-01         0.5  8.660254e-01
# 26022    14      53  ... -0.775711 -8.660254e-01         0.5 -9.510565e-01
#
#        d_month_cos     month_sin  month_cos  days_since_ny_sin  \
# 46343    -0.104528 -9.898214e-01  -0.142315          -0.770953
# 75701    -1.000000  9.096320e-01   0.415415           0.700978
# 89227    -0.809017 -5.406408e-01   0.841254          -0.957253
# 70825    -0.500000  7.557496e-01  -0.654861           0.990480
# 26022     0.309017 -2.449294e-16   1.000000          -0.596132
#
#        days_since_ny_cos  after_midnight
# 46343          -0.636892               0
# 75701           0.713183               0
# 89227           0.289252               0
# 70825          -0.137654               0
# 26022           0.802886               0
#
# [5 rows x 28 columns]

# %%
fl = FocalLoss(alpha=0.5, gamma=5)

# %%
model = lgb.LGBMClassifier(objective=fl.lgb_obj)

# %%
lgbm_params = {'boosting': 'gbdt',
               'bagging_freq': 1,
               'n_estimators': 10_000,
               'random_state': RANDOM_STATE,
               'silent': True,
               'bagging_fraction': 0.638782643397927,
               'feature_fraction': 0.5072049472753989,
               'learning_rate': 0.02238858415024258,
               'max_depth': 10,
               'min_data_in_leaf': 7,
               'reg_alpha': 4.16689412832005,
               'reg_lambda': 3.0220290348080594,
               'n_jobs': 4}

# %%
model.set_params(**lgbm_params)
# Out:
# LGBMClassifier(bagging_fraction=0.638782643397927, bagging_freq=1,
#                boosting='gbdt', feature_fraction=0.5072049472753989,
#                learning_rate=0.02238858415024258, max_depth=10,
#                min_data_in_leaf=7, n_estimators=10000, n_jobs=4,
#                objective=<bound method FocalLoss.lgb_obj of <__main__.FocalLoss object at 0x7feb3546ae80>>,
#                random_state=648, reg_alpha=4.16689412832005,
#                reg_lambda=3.0220290348080594)

# %%
X_tr, X_es, y_tr, y_es = train_test_split(X_train, y_train,
                                          test_size=0.1,
                                          shuffle=True,
                                          random_state=RANDOM_STATE)

# %%
# %%time
model.fit(X_tr, y_tr,
          eval_set=[(X_tr, y_tr), (X_es, y_es)],
          eval_metric=[fl.lgb_eval, 'auc'],
          init_score=fl.init_score(y_tr),
          eval_init_score=[fl.init_score(y_tr),
                           fl.init_score(y_es)],
          early_stopping_rounds=100,
          verbose=50)
# Out:
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] feature_fraction is set=0.5072049472753989, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5072049472753989
# [LightGBM] [Warning] bagging_fraction is set=0.638782643397927, subsample=1.0 will be ignored. Current value: bagging_fraction=0.638782643397927
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Training until validation scores don't improve for 100 rounds
# [50]	training's auc: 0.735157	training's binary_logloss: 6.41881	training's focal_loss: 0.00755538	valid_1's auc: 0.720662	valid_1's binary_logloss: 6.351	valid_1's focal_loss: 0.00756739
# [100]	training's auc: 0.748553	training's binary_logloss: 6.40808	training's focal_loss: 0.00733091	valid_1's auc: 0.729527	valid_1's binary_logloss: 6.341	valid_1's focal_loss: 0.00739125
# [150]	training's auc: 0.757969	training's binary_logloss: 6.3747	training's focal_loss: 0.00721137	valid_1's auc: 0.733682	valid_1's binary_logloss: 6.33172	valid_1's focal_loss: 0.00732183
# [200]	training's auc: 0.764318	training's binary_logloss: 6.25624	training's focal_loss: 0.00713602	valid_1's auc: 0.736195	valid_1's binary_logloss: 6.20938	valid_1's focal_loss: 0.00728503
# [250]	training's auc: 0.770003	training's binary_logloss: 6.14666	training's focal_loss: 0.00707323	valid_1's auc: 0.736941	valid_1's binary_logloss: 6.14376	valid_1's focal_loss: 0.00726749
# [300]	training's auc: 0.774569	training's binary_logloss: 6.03564	training's focal_loss: 0.00702337	valid_1's auc: 0.737716	valid_1's binary_logloss: 6.092	valid_1's focal_loss: 0.00725455
# [350]	training's auc: 0.779414	training's binary_logloss: 5.96596	training's focal_loss: 0.00697493	valid_1's auc: 0.738293	valid_1's binary_logloss: 6.02097	valid_1's focal_loss: 0.0072452
# [400]	training's auc: 0.782322	training's binary_logloss: 5.90942	training's focal_loss: 0.00694228	valid_1's auc: 0.738969	valid_1's binary_logloss: 5.97893	valid_1's focal_loss: 0.0072376
# [450]	training's auc: 0.785996	training's binary_logloss: 5.8634	training's focal_loss: 0.00690576	valid_1's auc: 0.739117	valid_1's binary_logloss: 5.95321	valid_1's focal_loss: 0.00723454
# [500]	training's auc: 0.788737	training's binary_logloss: 5.81727	training's focal_loss: 0.00687634	valid_1's auc: 0.739313	valid_1's binary_logloss: 5.92615	valid_1's focal_loss: 0.00723152
# [550]	training's auc: 0.791917	training's binary_logloss: 5.78544	training's focal_loss: 0.00684555	valid_1's auc: 0.739419	valid_1's binary_logloss: 5.91344	valid_1's focal_loss: 0.00722911
# [600]	training's auc: 0.794822	training's binary_logloss: 5.7532	training's focal_loss: 0.00681752	valid_1's auc: 0.739525	valid_1's binary_logloss: 5.89097	valid_1's focal_loss: 0.00722803
# [650]	training's auc: 0.79735	training's binary_logloss: 5.72097	training's focal_loss: 0.00679134	valid_1's auc: 0.739857	valid_1's binary_logloss: 5.87623	valid_1's focal_loss: 0.00722582
# [700]	training's auc: 0.800091	training's binary_logloss: 5.69116	training's focal_loss: 0.00676463	valid_1's auc: 0.739457	valid_1's binary_logloss: 5.8699	valid_1's focal_loss: 0.00722782
# Early stopping, best iteration is:
# [635]	training's auc: 0.796503	training's binary_logloss: 5.72744	training's focal_loss: 0.00679968	valid_1's auc: 0.739953	valid_1's binary_logloss: 5.88072	valid_1's focal_loss: 0.00722483
# CPU times: user 1min 21s, sys: 5.73 s, total: 1min 27s
# Wall time: 31.8 s
# LGBMClassifier(bagging_fraction=0.638782643397927, bagging_freq=1,
#                boosting='gbdt', feature_fraction=0.5072049472753989,
#                learning_rate=0.02238858415024258, max_depth=10,
#                min_data_in_leaf=7, n_estimators=10000, n_jobs=4,
#                objective=<bound method FocalLoss.lgb_obj of <__main__.FocalLoss object at 0x7feb3546ae80>>,
#                random_state=648, reg_alpha=4.16689412832005,
#                reg_lambda=3.0220290348080594)

# %%
lgb.plot_metric(model, metric='auc')
# Out:
# <AxesSubplot:title={'center':'Metric during training'}, xlabel='Iterations', ylabel='auc'>

# %%
fi = pd.Series(model.feature_importances_, index=X_tr.columns)

# %%
with pd.option_context('display.max_rows', None):
    display(fi.sort_values(ascending=False))
# Out:
# Origin               2219
# Dest                 2219
# days_since_ny_sin    1418
# DayofMonth           1335
# days_since_ny        1203
# days_since_ny_cos    1166
# Distance             1142
# DepTime              1140
# UniqueCarrier        1133
# secs_since_ny         681
# Month                 675
# minute_sin            586
# minute                514
# hour_sin              503
# hour_cos              416
# minute_cos            388
# hour                  372
# DayOfWeek             272
# d_month               194
# d_week_sin            166
# d_month_sin           136
# d_month_cos           120
# d_week                 68
# d_week_cos             66
# month_sin              54
# month                  40
# month_cos              29
# after_midnight          0
# dtype: int32

# %% [markdown]
# # Validate

# %%
def get_proba(X, model):
    return special.expit(model.predict(X))

# %%
tr_proba = get_proba(X_tr, model)
# Out:
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/sklearn.py:925: UserWarning: Cannot compute class probabilities or labels due to the usage of customized objective function.
# Returning raw scores instead.
#   warnings.warn("Cannot compute class probabilities or labels "

# %%
roc_auc_score(y_tr, tr_proba)
# Out:
# 0.7965034061865025

# %%
roc_auc_score(y_train, get_proba(X_train, model))
# Out:
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/sklearn.py:925: UserWarning: Cannot compute class probabilities or labels due to the usage of customized objective function.
# Returning raw scores instead.
#   warnings.warn("Cannot compute class probabilities or labels "
# 0.7909462743890358

# %%
roc_auc_score(y_test, get_proba(X_test, model))
# Out:
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/sklearn.py:925: UserWarning: Cannot compute class probabilities or labels due to the usage of customized objective function.
# Returning raw scores instead.
#   warnings.warn("Cannot compute class probabilities or labels "
# 0.7378213349964371

# %% [markdown]
# # Optuna

# %% [markdown]
# ## Prepare folds

# %%
cv_splitter = StratifiedKFold(shuffle=True, random_state=RANDOM_STATE)

# %%
train_ds = []
test_ds = []
for train_ind, test_ind in cv_splitter.split(X, y):
    X_train, y_train = X.iloc[train_ind], y.iloc[train_ind]
    X_test, y_test = X.iloc[test_ind], y.iloc[test_ind]

    enc.fit(X_train[cat_cols])

    X_train = preproc(X_train)
    X_test = preproc(X_test)
    
    train_ds.append((X_train, y_train))
    test_ds.append((X_test, y_test))
# Out:
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# <ipython-input-21-0555f0c157ea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hour'] = df.DepTime // 100
# <ipython-input-21-0555f0c157ea>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df.DepTime % 100
# <ipython-input-21-0555f0c157ea>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_month'] = df.DayofMonth.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_week'] = df.DayOfWeek.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df.Month.str[2:].astype(int)
# <ipython-input-29-6ca10571684d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['days_since_ny'] = dep_td.dt.days
# <ipython-input-29-6ca10571684d>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['secs_since_ny'] = dep_td.dt.seconds
# <ipython-input-35-02630819fc8c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col_name + '_sin'] = np.sin(2*np.pi/(max_val - min_val)*orig_vals)
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# <ipython-input-36-f252a9bbd96d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['after_midnight'] = 0
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# <ipython-input-21-0555f0c157ea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hour'] = df.DepTime // 100
# <ipython-input-21-0555f0c157ea>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df.DepTime % 100
# <ipython-input-21-0555f0c157ea>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_month'] = df.DayofMonth.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_week'] = df.DayOfWeek.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df.Month.str[2:].astype(int)
# <ipython-input-29-6ca10571684d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['days_since_ny'] = dep_td.dt.days
# <ipython-input-29-6ca10571684d>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['secs_since_ny'] = dep_td.dt.seconds
# <ipython-input-35-02630819fc8c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col_name + '_sin'] = np.sin(2*np.pi/(max_val - min_val)*orig_vals)
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# <ipython-input-36-f252a9bbd96d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['after_midnight'] = 0
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# <ipython-input-21-0555f0c157ea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hour'] = df.DepTime // 100
# <ipython-input-21-0555f0c157ea>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df.DepTime % 100
# <ipython-input-21-0555f0c157ea>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_month'] = df.DayofMonth.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_week'] = df.DayOfWeek.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df.Month.str[2:].astype(int)
# <ipython-input-29-6ca10571684d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['days_since_ny'] = dep_td.dt.days
# <ipython-input-29-6ca10571684d>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['secs_since_ny'] = dep_td.dt.seconds
# <ipython-input-35-02630819fc8c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col_name + '_sin'] = np.sin(2*np.pi/(max_val - min_val)*orig_vals)
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# <ipython-input-36-f252a9bbd96d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['after_midnight'] = 0
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# <ipython-input-21-0555f0c157ea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hour'] = df.DepTime // 100
# <ipython-input-21-0555f0c157ea>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df.DepTime % 100
# <ipython-input-21-0555f0c157ea>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_month'] = df.DayofMonth.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_week'] = df.DayOfWeek.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df.Month.str[2:].astype(int)
# <ipython-input-29-6ca10571684d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['days_since_ny'] = dep_td.dt.days
# <ipython-input-29-6ca10571684d>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['secs_since_ny'] = dep_td.dt.seconds
# <ipython-input-35-02630819fc8c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col_name + '_sin'] = np.sin(2*np.pi/(max_val - min_val)*orig_vals)
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# <ipython-input-36-f252a9bbd96d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['after_midnight'] = 0
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# <ipython-input-21-0555f0c157ea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hour'] = df.DepTime // 100
# <ipython-input-21-0555f0c157ea>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df.DepTime % 100
# <ipython-input-21-0555f0c157ea>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_month'] = df.DayofMonth.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_week'] = df.DayOfWeek.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df.Month.str[2:].astype(int)
# <ipython-input-29-6ca10571684d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['days_since_ny'] = dep_td.dt.days
# <ipython-input-29-6ca10571684d>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['secs_since_ny'] = dep_td.dt.seconds
# <ipython-input-35-02630819fc8c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col_name + '_sin'] = np.sin(2*np.pi/(max_val - min_val)*orig_vals)
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# <ipython-input-36-f252a9bbd96d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['after_midnight'] = 0
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# <ipython-input-21-0555f0c157ea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hour'] = df.DepTime // 100
# <ipython-input-21-0555f0c157ea>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df.DepTime % 100
# <ipython-input-21-0555f0c157ea>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_month'] = df.DayofMonth.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_week'] = df.DayOfWeek.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df.Month.str[2:].astype(int)
# <ipython-input-29-6ca10571684d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['days_since_ny'] = dep_td.dt.days
# <ipython-input-29-6ca10571684d>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['secs_since_ny'] = dep_td.dt.seconds
# <ipython-input-35-02630819fc8c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col_name + '_sin'] = np.sin(2*np.pi/(max_val - min_val)*orig_vals)
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# <ipython-input-36-f252a9bbd96d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['after_midnight'] = 0
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# <ipython-input-21-0555f0c157ea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hour'] = df.DepTime // 100
# <ipython-input-21-0555f0c157ea>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df.DepTime % 100
# <ipython-input-21-0555f0c157ea>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_month'] = df.DayofMonth.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_week'] = df.DayOfWeek.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df.Month.str[2:].astype(int)
# <ipython-input-29-6ca10571684d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['days_since_ny'] = dep_td.dt.days
# <ipython-input-29-6ca10571684d>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['secs_since_ny'] = dep_td.dt.seconds
# <ipython-input-35-02630819fc8c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col_name + '_sin'] = np.sin(2*np.pi/(max_val - min_val)*orig_vals)
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# <ipython-input-36-f252a9bbd96d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['after_midnight'] = 0
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# <ipython-input-21-0555f0c157ea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hour'] = df.DepTime // 100
# <ipython-input-21-0555f0c157ea>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df.DepTime % 100
# <ipython-input-21-0555f0c157ea>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_month'] = df.DayofMonth.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_week'] = df.DayOfWeek.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df.Month.str[2:].astype(int)
# <ipython-input-29-6ca10571684d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['days_since_ny'] = dep_td.dt.days
# <ipython-input-29-6ca10571684d>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['secs_since_ny'] = dep_td.dt.seconds
# <ipython-input-35-02630819fc8c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col_name + '_sin'] = np.sin(2*np.pi/(max_val - min_val)*orig_vals)
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# <ipython-input-36-f252a9bbd96d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['after_midnight'] = 0
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# <ipython-input-21-0555f0c157ea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hour'] = df.DepTime // 100
# <ipython-input-21-0555f0c157ea>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df.DepTime % 100
# <ipython-input-21-0555f0c157ea>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_month'] = df.DayofMonth.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_week'] = df.DayOfWeek.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df.Month.str[2:].astype(int)
# <ipython-input-29-6ca10571684d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['days_since_ny'] = dep_td.dt.days
# <ipython-input-29-6ca10571684d>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['secs_since_ny'] = dep_td.dt.seconds
# <ipython-input-35-02630819fc8c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col_name + '_sin'] = np.sin(2*np.pi/(max_val - min_val)*orig_vals)
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# <ipython-input-36-f252a9bbd96d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['after_midnight'] = 0
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# <ipython-input-21-0555f0c157ea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hour'] = df.DepTime // 100
# <ipython-input-21-0555f0c157ea>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minute'] = df.DepTime % 100
# <ipython-input-21-0555f0c157ea>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_month'] = df.DayofMonth.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['d_week'] = df.DayOfWeek.str[2:].astype(int)
# <ipython-input-21-0555f0c157ea>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df.Month.str[2:].astype(int)
# <ipython-input-29-6ca10571684d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['days_since_ny'] = dep_td.dt.days
# <ipython-input-29-6ca10571684d>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['secs_since_ny'] = dep_td.dt.seconds
# <ipython-input-35-02630819fc8c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col_name + '_sin'] = np.sin(2*np.pi/(max_val - min_val)*orig_vals)
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# <ipython-input-36-f252a9bbd96d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['after_midnight'] = 0
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
X.shape
# Out:
# (100000, 13)

# %%
def get_proba(X, model):
    return special.expit(model.predict(X))

# %%
def objective(trial):
    alpha = trial.suggest_float("alpha",
                                             0.0, 1.0)
    gamma = trial.suggest_float("gamma",
                                             0, 10)
    fl = FocalLoss(alpha=alpha,
                   gamma=gamma)
    
    lgbm_params = {'boosting': 'gbdt',
                   'bagging_fraction': trial.suggest_float("bagging_fraction",
                                                           0.5, 1.0),
                   'bagging_freq': 1,
                   'feature_fraction': trial.suggest_float("feature_fraction",
                                                           0.5, 1.0),
                   'learning_rate': trial.suggest_float("lr",
                                                        0.0001, 0.5),
                   'max_depth': trial.suggest_int("max_depth", 1, 15),
                   'min_data_in_leaf': trial.suggest_int("min_data_in_leaf",
                                                         1,
                                                         10000, log=True),
                   'n_estimators': 10_000,
                   'reg_alpha': trial.suggest_float("reg_alpha", 0, 10),
                   'reg_lambda': trial.suggest_float("reg_lambda", 0, 10),
                   'random_state': RANDOM_STATE,
                   'silent': True}

    metrics = []
    cv_splitter = StratifiedKFold(shuffle=True, random_state=RANDOM_STATE)
    for train_set, test_set in zip(train_ds, test_ds):
        X_train, y_train = train_set
        X_test, y_test = test_set

        X_tr, X_es, y_tr, y_es = train_test_split(X_train, y_train,
                                                  test_size=0.1,
                                                  shuffle=True,
                                                  random_state=RANDOM_STATE)
        model = lgb.LGBMClassifier()
        model.set_params(**lgbm_params)
        model.fit(X_tr, y_tr,
                  eval_set=[(X_tr, y_tr), (X_es, y_es)],
                  eval_metric=[fl.lgb_eval, 'auc'],
                  init_score=fl.init_score(y_tr),
                  eval_init_score=[fl.init_score(y_tr),
                                   fl.init_score(y_es)],
                  early_stopping_rounds=100,
                  verbose=0)
        auc = roc_auc_score(y_test, get_proba(X_test, model))
        metrics.append(auc)
    print(alpha, gamma)
    return sum(metrics) / 5

# %%
# %%time
optuna.logging.set_verbosity(optuna.logging.WARNING)
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=500)

trial = study.best_trial

pickle.dump(study, open('optuna_study_focal.pkl', 'wb'))
# Out:
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] feature_fraction is set=0.5365584074246481, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5365584074246481
# [LightGBM] [Warning] bagging_fraction is set=0.9341431526772006, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9341431526772006
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] feature_fraction is set=0.5365584074246481, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5365584074246481
# [LightGBM] [Warning] bagging_fraction is set=0.9341431526772006, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9341431526772006
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] feature_fraction is set=0.5365584074246481, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5365584074246481
# [LightGBM] [Warning] bagging_fraction is set=0.9341431526772006, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9341431526772006
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] feature_fraction is set=0.5365584074246481, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5365584074246481
# [LightGBM] [Warning] bagging_fraction is set=0.9341431526772006, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9341431526772006
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] feature_fraction is set=0.5365584074246481, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5365584074246481
# [LightGBM] [Warning] bagging_fraction is set=0.9341431526772006, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9341431526772006
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# 0.006137836619281245 6.140825467865858
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=43, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=43
# [LightGBM] [Warning] feature_fraction is set=0.6571211217405399, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6571211217405399
# [LightGBM] [Warning] bagging_fraction is set=0.8035925266955743, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8035925266955743
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=43, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=43
# [LightGBM] [Warning] feature_fraction is set=0.6571211217405399, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6571211217405399
# [LightGBM] [Warning] bagging_fraction is set=0.8035925266955743, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8035925266955743
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=43, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=43
# [LightGBM] [Warning] feature_fraction is set=0.6571211217405399, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6571211217405399
# [LightGBM] [Warning] bagging_fraction is set=0.8035925266955743, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8035925266955743
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=43, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=43
# [LightGBM] [Warning] feature_fraction is set=0.6571211217405399, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6571211217405399
# [LightGBM] [Warning] bagging_fraction is set=0.8035925266955743, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8035925266955743
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=43, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=43
# [LightGBM] [Warning] feature_fraction is set=0.6571211217405399, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6571211217405399
# [LightGBM] [Warning] bagging_fraction is set=0.8035925266955743, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8035925266955743
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# 0.8677495045613469 1.48920531953737
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] feature_fraction is set=0.5904967716862646, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5904967716862646
# [LightGBM] [Warning] bagging_fraction is set=0.6611117291060853, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6611117291060853
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] feature_fraction is set=0.5904967716862646, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5904967716862646
# [LightGBM] [Warning] bagging_fraction is set=0.6611117291060853, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6611117291060853
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] feature_fraction is set=0.5904967716862646, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5904967716862646
# [LightGBM] [Warning] bagging_fraction is set=0.6611117291060853, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6611117291060853
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] feature_fraction is set=0.5904967716862646, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5904967716862646
# [LightGBM] [Warning] bagging_fraction is set=0.6611117291060853, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6611117291060853
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] feature_fraction is set=0.5904967716862646, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5904967716862646
# [LightGBM] [Warning] bagging_fraction is set=0.6611117291060853, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6611117291060853
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# 0.9985444486955736 9.682668413668367
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=45, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=45
# [LightGBM] [Warning] feature_fraction is set=0.7890515677218503, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7890515677218503
# [LightGBM] [Warning] bagging_fraction is set=0.6150310585781469, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6150310585781469
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=45, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=45
# [LightGBM] [Warning] feature_fraction is set=0.7890515677218503, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7890515677218503
# [LightGBM] [Warning] bagging_fraction is set=0.6150310585781469, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6150310585781469
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=45, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=45
# [LightGBM] [Warning] feature_fraction is set=0.7890515677218503, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7890515677218503
# [LightGBM] [Warning] bagging_fraction is set=0.6150310585781469, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6150310585781469
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=45, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=45
# [LightGBM] [Warning] feature_fraction is set=0.7890515677218503, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7890515677218503
# [LightGBM] [Warning] bagging_fraction is set=0.6150310585781469, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6150310585781469
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=45, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=45
# [LightGBM] [Warning] feature_fraction is set=0.7890515677218503, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7890515677218503
# [LightGBM] [Warning] bagging_fraction is set=0.6150310585781469, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6150310585781469
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# 0.37754848395095997 5.219228084971508
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=34, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=34
# [LightGBM] [Warning] feature_fraction is set=0.9928993634397911, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9928993634397911
# [LightGBM] [Warning] bagging_fraction is set=0.7799714294452276, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7799714294452276
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=34, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=34
# [LightGBM] [Warning] feature_fraction is set=0.9928993634397911, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9928993634397911
# [LightGBM] [Warning] bagging_fraction is set=0.7799714294452276, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7799714294452276
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=34, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=34
# [LightGBM] [Warning] feature_fraction is set=0.9928993634397911, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9928993634397911
# [LightGBM] [Warning] bagging_fraction is set=0.7799714294452276, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7799714294452276
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=34, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=34
# [LightGBM] [Warning] feature_fraction is set=0.9928993634397911, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9928993634397911
# [LightGBM] [Warning] bagging_fraction is set=0.7799714294452276, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7799714294452276
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=34, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=34
# [LightGBM] [Warning] feature_fraction is set=0.9928993634397911, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9928993634397911
# [LightGBM] [Warning] bagging_fraction is set=0.7799714294452276, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7799714294452276
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# 0.48043502936665716 7.256189233232229
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] feature_fraction is set=0.7978399837630679, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7978399837630679
# [LightGBM] [Warning] bagging_fraction is set=0.875229783971166, subsample=1.0 will be ignored. Current value: bagging_fraction=0.875229783971166
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] feature_fraction is set=0.7978399837630679, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7978399837630679
# [LightGBM] [Warning] bagging_fraction is set=0.875229783971166, subsample=1.0 will be ignored. Current value: bagging_fraction=0.875229783971166
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] feature_fraction is set=0.7978399837630679, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7978399837630679
# [LightGBM] [Warning] bagging_fraction is set=0.875229783971166, subsample=1.0 will be ignored. Current value: bagging_fraction=0.875229783971166
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] feature_fraction is set=0.7978399837630679, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7978399837630679
# [LightGBM] [Warning] bagging_fraction is set=0.875229783971166, subsample=1.0 will be ignored. Current value: bagging_fraction=0.875229783971166
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] feature_fraction is set=0.7978399837630679, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7978399837630679
# [LightGBM] [Warning] bagging_fraction is set=0.875229783971166, subsample=1.0 will be ignored. Current value: bagging_fraction=0.875229783971166
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# 0.8506168922024525 1.48855040936553
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] feature_fraction is set=0.7539469172259401, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7539469172259401
# [LightGBM] [Warning] bagging_fraction is set=0.6624005190390787, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6624005190390787
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] feature_fraction is set=0.7539469172259401, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7539469172259401
# [LightGBM] [Warning] bagging_fraction is set=0.6624005190390787, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6624005190390787
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] feature_fraction is set=0.7539469172259401, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7539469172259401
# [LightGBM] [Warning] bagging_fraction is set=0.6624005190390787, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6624005190390787
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] feature_fraction is set=0.7539469172259401, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7539469172259401
# [LightGBM] [Warning] bagging_fraction is set=0.6624005190390787, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6624005190390787
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] feature_fraction is set=0.7539469172259401, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7539469172259401
# [LightGBM] [Warning] bagging_fraction is set=0.6624005190390787, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6624005190390787
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# 0.48153867456567034 5.316114687791575
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=422, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=422
# [LightGBM] [Warning] feature_fraction is set=0.5421129238599833, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5421129238599833
# [LightGBM] [Warning] bagging_fraction is set=0.9847368521511213, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9847368521511213
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=422, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=422
# [LightGBM] [Warning] feature_fraction is set=0.5421129238599833, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5421129238599833
# [LightGBM] [Warning] bagging_fraction is set=0.9847368521511213, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9847368521511213
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=422, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=422
# [LightGBM] [Warning] feature_fraction is set=0.5421129238599833, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5421129238599833
# [LightGBM] [Warning] bagging_fraction is set=0.9847368521511213, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9847368521511213
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=422, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=422
# [LightGBM] [Warning] feature_fraction is set=0.5421129238599833, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5421129238599833
# [LightGBM] [Warning] bagging_fraction is set=0.9847368521511213, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9847368521511213
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=422, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=422
# [LightGBM] [Warning] feature_fraction is set=0.5421129238599833, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5421129238599833
# [LightGBM] [Warning] bagging_fraction is set=0.9847368521511213, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9847368521511213
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# 0.9396124650140767 6.9628618759288265
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=8, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=8
# [LightGBM] [Warning] feature_fraction is set=0.5563543409212577, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5563543409212577
# [LightGBM] [Warning] bagging_fraction is set=0.6585789862731581, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6585789862731581
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=8, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=8
# [LightGBM] [Warning] feature_fraction is set=0.5563543409212577, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5563543409212577
# [LightGBM] [Warning] bagging_fraction is set=0.6585789862731581, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6585789862731581
# ...
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] feature_fraction is set=0.5102831724397209, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5102831724397209
# [LightGBM] [Warning] bagging_fraction is set=0.7809502693467004, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7809502693467004
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] feature_fraction is set=0.5102831724397209, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5102831724397209
# [LightGBM] [Warning] bagging_fraction is set=0.7809502693467004, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7809502693467004
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] feature_fraction is set=0.5102831724397209, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5102831724397209
# [LightGBM] [Warning] bagging_fraction is set=0.7809502693467004, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7809502693467004
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# 0.08164416236337729 2.115986343550098
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=15, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=15
# [LightGBM] [Warning] feature_fraction is set=0.5241713480510958, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5241713480510958
# [LightGBM] [Warning] bagging_fraction is set=0.7587566671410894, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7587566671410894
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=15, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=15
# [LightGBM] [Warning] feature_fraction is set=0.5241713480510958, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5241713480510958
# [LightGBM] [Warning] bagging_fraction is set=0.7587566671410894, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7587566671410894
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=15, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=15
# [LightGBM] [Warning] feature_fraction is set=0.5241713480510958, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5241713480510958
# [LightGBM] [Warning] bagging_fraction is set=0.7587566671410894, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7587566671410894
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=15, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=15
# [LightGBM] [Warning] feature_fraction is set=0.5241713480510958, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5241713480510958
# [LightGBM] [Warning] bagging_fraction is set=0.7587566671410894, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7587566671410894
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=15, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=15
# [LightGBM] [Warning] feature_fraction is set=0.5241713480510958, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5241713480510958
# [LightGBM] [Warning] bagging_fraction is set=0.7587566671410894, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7587566671410894
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# 0.025743149374011523 2.2146892451125724
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=17, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=17
# [LightGBM] [Warning] feature_fraction is set=0.535029997879158, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.535029997879158
# [LightGBM] [Warning] bagging_fraction is set=0.7124086262589697, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7124086262589697
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=17, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=17
# [LightGBM] [Warning] feature_fraction is set=0.535029997879158, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.535029997879158
# [LightGBM] [Warning] bagging_fraction is set=0.7124086262589697, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7124086262589697
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=17, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=17
# [LightGBM] [Warning] feature_fraction is set=0.535029997879158, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.535029997879158
# [LightGBM] [Warning] bagging_fraction is set=0.7124086262589697, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7124086262589697
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=17, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=17
# [LightGBM] [Warning] feature_fraction is set=0.535029997879158, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.535029997879158
# [LightGBM] [Warning] bagging_fraction is set=0.7124086262589697, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7124086262589697
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=17, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=17
# [LightGBM] [Warning] feature_fraction is set=0.535029997879158, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.535029997879158
# [LightGBM] [Warning] bagging_fraction is set=0.7124086262589697, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7124086262589697
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# 0.045877999709409034 1.9644352315413336
# CPU times: user 3d 1h 21min 42s, sys: 1h 41min 12s, total: 3d 3h 2min 54s
# Wall time: 1d 11h 35min 6s

# %%
trial
# Out:
# FrozenTrial(number=338, values=[0.6793143865657552], datetime_start=datetime.datetime(2021, 4, 30, 3, 13, 8, 363680), datetime_complete=datetime.datetime(2021, 4, 30, 3, 15, 9, 989313), params={'alpha': 0.12979953038037745, 'gamma': 1.5932315234240955, 'bagging_fraction': 0.7084816260305064, 'feature_fraction': 0.5006463341056869, 'lr': 0.03447282055560186, 'max_depth': 7, 'min_data_in_leaf': 11, 'reg_alpha': 6.313930722574406, 'reg_lambda': 1.656371355086308}, distributions={'alpha': UniformDistribution(high=1.0, low=0.0), 'gamma': UniformDistribution(high=10.0, low=0.0), 'bagging_fraction': UniformDistribution(high=1.0, low=0.5), 'feature_fraction': UniformDistribution(high=1.0, low=0.5), 'lr': UniformDistribution(high=0.5, low=0.0001), 'max_depth': IntUniformDistribution(high=15, low=1, step=1), 'min_data_in_leaf': IntLogUniformDistribution(high=10000, low=1, step=1), 'reg_alpha': UniformDistribution(high=10.0, low=0.0), 'reg_lambda': UniformDistribution(high=10.0, low=0.0)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=338, state=TrialState.COMPLETE, value=None)

# %%
trial.params
# Out:
# {'alpha': 0.12979953038037745,
#  'gamma': 1.5932315234240955,
#  'bagging_fraction': 0.7084816260305064,
#  'feature_fraction': 0.5006463341056869,
#  'lr': 0.03447282055560186,
#  'max_depth': 7,
#  'min_data_in_leaf': 11,
#  'reg_alpha': 6.313930722574406,
#  'reg_lambda': 1.656371355086308}

# %% [markdown]
# # Commit

# %% [markdown]
# ## Refit on full dataset

# %%
enc = OrdinalEncoder(cols=cat_cols,
                     handle_missing='return_nan',
                     handle_unknown='return_nan')

# %%
enc.fit(X[cat_cols]);
# Out:
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
X = preproc(X)

# %%
X_tr, X_es, y_tr, y_es = train_test_split(X, y,
                                          test_size=0.1,
                                          shuffle=True,
                                          random_state=RANDOM_STATE)

# %%
# %%time
model.fit(X_tr, y_tr,
          eval_set=[(X_tr, y_tr), (X_es, y_es)],
          eval_metric=[fl.lgb_eval, 'auc'],
          init_score=fl.init_score(y_tr),
          eval_init_score=[fl.init_score(y_tr),
                           fl.init_score(y_es)],
          early_stopping_rounds=100,
          verbose=50)
# Out:
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] feature_fraction is set=0.5072049472753989, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5072049472753989
# [LightGBM] [Warning] bagging_fraction is set=0.638782643397927, subsample=1.0 will be ignored. Current value: bagging_fraction=0.638782643397927
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Training until validation scores don't improve for 100 rounds
# [50]	training's auc: 0.734156	training's binary_logloss: 6.36141	training's focal_loss: 0.00751714	valid_1's auc: 0.71673	valid_1's binary_logloss: 6.45115	valid_1's focal_loss: 0.00762415
# [100]	training's auc: 0.746804	training's binary_logloss: 6.35075	training's focal_loss: 0.00730044	valid_1's auc: 0.725429	valid_1's binary_logloss: 6.44105	valid_1's focal_loss: 0.00745634
# [150]	training's auc: 0.756031	training's binary_logloss: 6.27994	training's focal_loss: 0.00718642	valid_1's auc: 0.73113	valid_1's binary_logloss: 6.36409	valid_1's focal_loss: 0.00738224
# [200]	training's auc: 0.762768	training's binary_logloss: 6.15088	training's focal_loss: 0.00710938	valid_1's auc: 0.734414	valid_1's binary_logloss: 6.25103	valid_1's focal_loss: 0.00734359
# [250]	training's auc: 0.768131	training's binary_logloss: 6.04411	training's focal_loss: 0.00705164	valid_1's auc: 0.737152	valid_1's binary_logloss: 6.16897	valid_1's focal_loss: 0.00731665
# [300]	training's auc: 0.772718	training's binary_logloss: 5.9659	training's focal_loss: 0.00700278	valid_1's auc: 0.738992	valid_1's binary_logloss: 6.10948	valid_1's focal_loss: 0.0072983
# [350]	training's auc: 0.776242	training's binary_logloss: 5.90061	training's focal_loss: 0.00696473	valid_1's auc: 0.740312	valid_1's binary_logloss: 6.06679	valid_1's focal_loss: 0.00728425
# [400]	training's auc: 0.78023	training's binary_logloss: 5.84958	training's focal_loss: 0.006926	valid_1's auc: 0.740982	valid_1's binary_logloss: 6.0268	valid_1's focal_loss: 0.00727675
# [450]	training's auc: 0.783568	training's binary_logloss: 5.79566	training's focal_loss: 0.00689285	valid_1's auc: 0.742076	valid_1's binary_logloss: 5.98632	valid_1's focal_loss: 0.00726769
# [500]	training's auc: 0.786984	training's binary_logloss: 5.75767	training's focal_loss: 0.00685952	valid_1's auc: 0.742691	valid_1's binary_logloss: 5.9485	valid_1's focal_loss: 0.00726121
# [550]	training's auc: 0.789789	training's binary_logloss: 5.71855	training's focal_loss: 0.0068309	valid_1's auc: 0.743567	valid_1's binary_logloss: 5.92032	valid_1's focal_loss: 0.00725391
# [600]	training's auc: 0.792689	training's binary_logloss: 5.68521	training's focal_loss: 0.00680318	valid_1's auc: 0.744409	valid_1's binary_logloss: 5.90336	valid_1's focal_loss: 0.00724575
# [650]	training's auc: 0.795098	training's binary_logloss: 5.65358	training's focal_loss: 0.00677907	valid_1's auc: 0.74474	valid_1's binary_logloss: 5.87605	valid_1's focal_loss: 0.00724299
# [700]	training's auc: 0.797479	training's binary_logloss: 5.63034	training's focal_loss: 0.00675575	valid_1's auc: 0.745125	valid_1's binary_logloss: 5.85917	valid_1's focal_loss: 0.00723989
# [750]	training's auc: 0.7999	training's binary_logloss: 5.60716	training's focal_loss: 0.00673241	valid_1's auc: 0.745658	valid_1's binary_logloss: 5.85046	valid_1's focal_loss: 0.00723599
# [800]	training's auc: 0.802325	training's binary_logloss: 5.59036	training's focal_loss: 0.00670916	valid_1's auc: 0.746002	valid_1's binary_logloss: 5.82048	valid_1's focal_loss: 0.00723336
# [850]	training's auc: 0.804443	training's binary_logloss: 5.56643	training's focal_loss: 0.00668768	valid_1's auc: 0.746751	valid_1's binary_logloss: 5.80028	valid_1's focal_loss: 0.00722745
# [900]	training's auc: 0.806817	training's binary_logloss: 5.54984	training's focal_loss: 0.00666498	valid_1's auc: 0.746866	valid_1's binary_logloss: 5.77975	valid_1's focal_loss: 0.00722608
# [950]	training's auc: 0.809123	training's binary_logloss: 5.53092	training's focal_loss: 0.00664248	valid_1's auc: 0.747213	valid_1's binary_logloss: 5.78565	valid_1's focal_loss: 0.00722413
# [1000]	training's auc: 0.81146	training's binary_logloss: 5.5114	training's focal_loss: 0.00661987	valid_1's auc: 0.747783	valid_1's binary_logloss: 5.76922	valid_1's focal_loss: 0.00721957
# [1050]	training's auc: 0.813374	training's binary_logloss: 5.49829	training's focal_loss: 0.00660091	valid_1's auc: 0.748129	valid_1's binary_logloss: 5.75707	valid_1's focal_loss: 0.00721724
# [1100]	training's auc: 0.815318	training's binary_logloss: 5.48375	training's focal_loss: 0.00658076	valid_1's auc: 0.748303	valid_1's binary_logloss: 5.74898	valid_1's focal_loss: 0.0072167
# [1150]	training's auc: 0.81724	training's binary_logloss: 5.46108	training's focal_loss: 0.00656155	valid_1's auc: 0.748508	valid_1's binary_logloss: 5.72182	valid_1's focal_loss: 0.00721478
# [1200]	training's auc: 0.819127	training's binary_logloss: 5.44337	training's focal_loss: 0.00654218	valid_1's auc: 0.748633	valid_1's binary_logloss: 5.7256	valid_1's focal_loss: 0.00721421
# [1250]	training's auc: 0.820901	training's binary_logloss: 5.42811	training's focal_loss: 0.00652513	valid_1's auc: 0.748631	valid_1's binary_logloss: 5.72117	valid_1's focal_loss: 0.0072141
# [1300]	training's auc: 0.822741	training's binary_logloss: 5.41295	training's focal_loss: 0.00650647	valid_1's auc: 0.748657	valid_1's binary_logloss: 5.71209	valid_1's focal_loss: 0.00721408
# [1350]	training's auc: 0.824554	training's binary_logloss: 5.39324	training's focal_loss: 0.00648705	valid_1's auc: 0.749123	valid_1's binary_logloss: 5.70186	valid_1's focal_loss: 0.00721162
# [1400]	training's auc: 0.826253	training's binary_logloss: 5.37035	training's focal_loss: 0.00646914	valid_1's auc: 0.749376	valid_1's binary_logloss: 5.68844	valid_1's focal_loss: 0.00720916
# [1450]	training's auc: 0.827658	training's binary_logloss: 5.35702	training's focal_loss: 0.00645409	valid_1's auc: 0.74944	valid_1's binary_logloss: 5.69022	valid_1's focal_loss: 0.00720878
# [1500]	training's auc: 0.829189	training's binary_logloss: 5.34028	training's focal_loss: 0.00643736	valid_1's auc: 0.74942	valid_1's binary_logloss: 5.66661	valid_1's focal_loss: 0.00720965
# [1550]	training's auc: 0.830841	training's binary_logloss: 5.32552	training's focal_loss: 0.00641962	valid_1's auc: 0.749581	valid_1's binary_logloss: 5.65904	valid_1's focal_loss: 0.00720894
# [1600]	training's auc: 0.832127	training's binary_logloss: 5.30678	training's focal_loss: 0.00640502	valid_1's auc: 0.749821	valid_1's binary_logloss: 5.65137	valid_1's focal_loss: 0.00720778
# [1650]	training's auc: 0.833612	training's binary_logloss: 5.29799	training's focal_loss: 0.0063892	valid_1's auc: 0.749943	valid_1's binary_logloss: 5.63367	valid_1's focal_loss: 0.00720773
# [1700]	training's auc: 0.834889	training's binary_logloss: 5.28494	training's focal_loss: 0.00637504	valid_1's auc: 0.750118	valid_1's binary_logloss: 5.62878	valid_1's focal_loss: 0.00720667
# [1750]	training's auc: 0.836093	training's binary_logloss: 5.27479	training's focal_loss: 0.00636114	valid_1's auc: 0.7501	valid_1's binary_logloss: 5.62186	valid_1's focal_loss: 0.0072066
# [1800]	training's auc: 0.837204	training's binary_logloss: 5.26161	training's focal_loss: 0.00634859	valid_1's auc: 0.750264	valid_1's binary_logloss: 5.62058	valid_1's focal_loss: 0.00720548
# [1850]	training's auc: 0.838496	training's binary_logloss: 5.24515	training's focal_loss: 0.00633409	valid_1's auc: 0.750378	valid_1's binary_logloss: 5.61893	valid_1's focal_loss: 0.00720442
# [1900]	training's auc: 0.83972	training's binary_logloss: 5.22703	training's focal_loss: 0.00632128	valid_1's auc: 0.750417	valid_1's binary_logloss: 5.60952	valid_1's focal_loss: 0.00720401
# Early stopping, best iteration is:
# [1821]	training's auc: 0.837741	training's binary_logloss: 5.2526	training's focal_loss: 0.00634237	valid_1's auc: 0.750454	valid_1's binary_logloss: 5.61178	valid_1's focal_loss: 0.00720406
# CPU times: user 5min 28s, sys: 14.7 s, total: 5min 43s
# Wall time: 1min 32s
# LGBMClassifier(bagging_fraction=0.638782643397927, bagging_freq=1,
#                boosting='gbdt', feature_fraction=0.5072049472753989,
#                learning_rate=0.02238858415024258, max_depth=10,
#                min_data_in_leaf=7, n_estimators=10000, n_jobs=4,
#                objective=<bound method FocalLoss.lgb_obj of <__main__.FocalLoss object at 0x7feb3546ae80>>,
#                random_state=648, reg_alpha=4.16689412832005,
#                reg_lambda=3.0220290348080594)

# %% [markdown]
# ## Prepare test

# %%
test = preproc(test)

# %%
test['dep_delayed_15min'] = get_proba(test.drop(target_name,
                                                          axis=1,
                                                          errors='ignore'),
                                      model)
# Out:
# /Users/aapiskotin/opt/anaconda3/lib/python3.8/site-packages/lightgbm/sklearn.py:925: UserWarning: Cannot compute class probabilities or labels due to the usage of customized objective function.
# Returning raw scores instead.
#   warnings.warn("Cannot compute class probabilities or labels "

# %%
test['dep_delayed_15min'].to_csv(data_path.joinpath('submit.csv'), index_label='id')

# %% [markdown]
# # Next Steps

# %% [markdown]
# * Grid Search through params
# * datetime engineering (sin/cos transform, DepTime limits transform(?))

# %% [markdown]
# # Notes

# %% [markdown]
# * OHE sucks since model just doesn't use those features
# * there are only 1 after 2400

# %% [markdown]
# __Best Score__: 0.72970
